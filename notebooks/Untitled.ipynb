# %%
# 0) Ver qué intérprete y entorno estás usando
import sys, os
print("Python:", sys.executable)
print("Conda env:", os.environ.get("CONDA_DEFAULT_ENV"))
# Out:
# Python: C:\Users\Norman Sabillon 2022\anaconda3\envs\mi_entorno_ml\python.exe
# Conda env: mi_entorno_ml
