# %% [markdown]
# ### Paso 1: Importar la Librería Pandas

# %%
import pandas as pd

# %% [markdown]
# Le damos el alias pd por convención, para no tener que escribir "pandas" cada vez.

# %% [markdown]
# ### Paso 2: Leer el Archivo de Texto (Delimitado por Tabulaciones)

# %%
# Especificamos la ruta al archivo dentro de nuestro proyecto
ruta_archivo = '../datos/Geografia.txt'

# Usamos la función read_csv, especificando que el separador es una tabulación ('\t')
df = pd.read_csv(ruta_archivo, sep='\t')

# %% [markdown]
# ### Paso 3: Visualizar los Datos

# %%
# Mostramos las primeras 5 filas de nuestro DataFrame
df.head()
# Out:
#    objectid  cod_depto      depto  cod_municipio      municipio  shape_Length  \
# 0         2          1  ATLANTIDA            103        Esparta      1.497917
# 1         3          1  ATLANTIDA            104        Jutiapa      1.035751
# 2         4          1  ATLANTIDA            105      La Masica      1.296319
# 3         5          1  ATLANTIDA            106  San Francisco      0.975459
# 4         6          1  ATLANTIDA            108        Arizona      1.513013
#
#    shape_Area  ISO      Pais VARNAME_1     ENGTYPE_2     TYPE_2     NAME_1  \
# 0    0.038841  HND  Honduras       NaN  Municipality  Municipio  ATLANTIDA
# 1    0.044913  HND  Honduras       NaN  Municipality  Municipio  ATLANTIDA
# 2    0.039500  HND  Honduras       NaN  Municipality  Municipio  ATLANTIDA
# 3    0.023811  HND  Honduras       NaN  Municipality  Municipio  ATLANTIDA
# 4    0.044767  HND  Honduras       NaN  Municipality  Municipio  ATLANTIDA
#
#   DEPARTAMENTO     MUNICIPIOS                DEPTO_MUN  Columna1  Columna2  \
# 0    ATLANTIDA        ESPARTA        ATLANTIDA,ESPARTA       NaN       NaN
# 1    ATLANTIDA        JUTIAPA        ATLANTIDA,JUTIAPA       NaN       NaN
# 2    ATLANTIDA      LA MASICA      ATLANTIDA,LA MASICA       NaN       NaN
# 3    ATLANTIDA  SAN FRANCISCO  ATLANTIDA,SAN FRANCISCO       NaN       NaN
# 4    ATLANTIDA        ARIZONA        ATLANTIDA,ARIZONA       NaN       NaN
#
#    Índice       REGION
# 0       1  Nororiental
# 1       2  Nororiental
# 2       3  Nororiental
# 3       4  Nororiental
# 4       5  Nororiental
